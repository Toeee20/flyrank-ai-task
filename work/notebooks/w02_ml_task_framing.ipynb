# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# Classification. As an ML Engineering intern, I work with machine learning systems that predict categories from data. My focus is on building and improving the pipelines, models, and deployment processes that support accurate classification tasks.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# I would predict whether a person is at risk of diabetes (Yes/No). The label comes from an observed outcome based on medical records and health indicators collected from real individuals.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# F1 Score. A good model should achieve an F1 Score of at least 0.80 because it balances precision and recall, reducing both false positives and false negatives.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.DataFrame({
    "Age": [25, 48, 35],
    "BMI": [22.5, 31.2, 27.8],
    "Exercise": [4, 1, 3],
    "Diabetes_Risk": ["No", "Yes", "No"]
})

display(df)

print("\nUnit of analysis:")
print("One row = one individual person")
# Out:
#    Age   BMI  Exercise Diabetes_Risk
# 0   25  22.5         4            No
# 1   48  31.2         1           Yes
# 2   35  27.8         3            No
# Unit of analysis:
# One row = one individual person

# %% [markdown]
# One row represents one individual person. Each row contains demographic, lifestyle, and health-related features that are used to predict diabetes risk.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# Diabetes risk depends on many interacting factors such as age, BMI, diet, exercise habits, and family history. Simple if-then rules cannot capture these complex relationships, while machine learning can learn patterns from large amounts of data and make more accurate predictions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
